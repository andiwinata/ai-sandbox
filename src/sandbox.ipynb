# %%
from bertopic import BERTopic
from datasets import load_dataset
from sklearn.feature_extraction.text import CountVectorizer

data = load_dataset("HuggingFaceH4/h4_10k_prompts_ranked_gen")
docs = data["train_gen"]["prompt"]

zeroshot_topic_list = ['searching knowledge', 'answer coding problem', 'summarizing', 'rephrasing', 'roleplay', 'translate', 'generate content']
vectorizer_model = CountVectorizer(stop_words="english")

topic_model = BERTopic(
    min_topic_size=20,
    zeroshot_topic_list=zeroshot_topic_list,
    zeroshot_min_similarity=.25,
    vectorizer_model=vectorizer_model
)

topics, probs = topic_model.fit_transform(docs)
topic_model.get_topic_info()
# Out:
#     Topic  Count                                      Name  \
# 0       0    494                     answer coding problem
# 1       1    412                               summarizing
# 2       2    259                          generate content
# 3       3    253                       searching knowledge
# 4       4    208                                  roleplay
# ..    ...    ...                                       ...
# 61     61     22                  53_css_attrx_attry_const
# 62     62     21            54_slack_chat_credential_oauth
# 63     63     21                55_frac_mean_stock_numbers
# 64     64     21             56_god_church_jehovah_leaders
# 65     65     21  57_differential_equation_equations_solve
#
#                                        Representation  \
# 0   [code, answer, number, snippet, given, functio...
# 1   [story, write, essay, use, text, paragraph, wr...
# 2   [content, generate, create, html, write, websi...
# 3   [search, keyword, data, learning, list, ai, ke...
# 4   [play, character, team, game, like, players, o...
# ..                                                ...
# 61  [css, attrx, attry, const, 20px, marginbottom,...
# 62  [slack, chat, credential, oauth, app, chatbot,...
# 63  [frac, mean, stock, numbers, median, index1, w...
# 64  [god, church, jehovah, leaders, leadership, mi...
# 65  [differential, equation, equations, solve, par...
#
#                                   Representative_Docs
# 0   [You are given a code snippet that contains a ...
# 1   [Develop a detailed writing prompt that challe...
# 2   [I Want You To Act As A Content Writer Very Pr...
# 3   [Please ignore all previous instructions. I wa...
# 4   [ENTRY 2 \n\nVal's Early Life\n\n\*\*\n\nStayi...
# ..                                                ...
# 61  [can you make a css design for this code\n\nMy...
# 62  [I am looking to develop a highly sophisticate...
# 63  [explain how to calculate mean, mode and media...
# 64  [Please summarize the following:\n\nThere was ...
# 65  [What are some 5 math equations that I can sol...
#
# [66 rows x 5 columns]

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### Downgrading numpy
#
# To 1.22.4 because bertopic does not work with seed topic
# https://github.com/MaartenGr/BERTopic/issues/1814

# %%
from bertopic import BERTopic
from datasets import load_dataset
from sklearn.feature_extraction.text import CountVectorizer

import numpy
print(f"Version: {numpy.__version__}")

data = load_dataset("HuggingFaceH4/h4_10k_prompts_ranked_gen")
docs = data["train_gen"]["prompt"]

vectorizer_model = CountVectorizer(stop_words="english")

seed_topic_list = [
                   ["when", 'date', 'time'],
                   ["who"],
                   ['where'],
                   ['how'],
                   ["rephrase", 'reword'],
                   ['translate'],
                   ["extract"],
                   ['code', 'coding', 'python'],
                   ['imagine', 'act', 'assume', 'role']
                  ]
# searching knowledge', 'answer coding problem', 'summarizing', 'rephrasing', 'roleplay', 'translate', 'generate content

topic_model = BERTopic(
    seed_topic_list=seed_topic_list,
    vectorizer_model=vectorizer_model,
    min_topic_size=25
)

topics, probs = topic_model.fit_transform(docs)
topic_model.get_topic_info()
# Out:
# Version: 1.22.4
#      Topic  Count                                               Name  \
# 0       -1   3679                         -1_code_function_write_use
# 1        0    314                        0_time_date_null_varchar255
# 2        1    310            1_proxysetheader_1111_english_translate
# 3        2    298                      2_india_router_hibiscus_cache
# 4        3    293                           3_file_com_glass_extract
# ..     ...    ...                                                ...
# 107    106     10                106_marketing_harvard_injaz_digital
# 108    107     10  107_matrix_var_matrix2_consolelogmatrixtologst...
# 109    108     10    108_programming_languages_specifcs_developergpt
# 110    109     10                   109_encryption_salt_iv_encrypted
# 111    110     10                   110_lactase_hair_truhitte_camera
#
#                                         Representation  \
# 0    [code, function, write, use, using, python, sn...
# 1    [time, date, null, varchar255, day, pixel, yea...
# 2    [proxysetheader, 1111, english, translate, mea...
# 3    [india, router, hibiscus, cache, newwidth, cre...
# 4    [file, com, glass, extract, shaker, shot, cons...
# ..                                                 ...
# 107  [marketing, harvard, injaz, digital, months, s...
# 108  [matrix, var, matrix2, consolelogmatrixtologst...
# 109  [programming, languages, specifcs, developergp...
# 110  [encryption, salt, iv, encrypted, decryption, ...
# 111  [lactase, hair, truhitte, camera, pmapv, bht, ...
#
#                                    Representative_Docs
# 0    [Web search results:\n\n[1] "A "listicle" is a...
# 1    [Ans: August 23 , 1994\nQues: On August 23, 19...
# 2    [You are currently an online teaching platform...
# 3    [Given the text: Malvaceae week :: Hibiscus sa...
# 4    [rearrange this data in table format that incl...
# ..                                                 ...
# 107  [Kayvon.AI\n\nKayvon Kay's new AI allows sales...
# 108  [You are working with a codebase that includes...
# 109  [What's the hardest programming language to le...
# 110  [How can I implement AES encryption algorithm ...
# 111  [Utilizing your knowledge of syntax and vocabu...
#
# [112 rows x 5 columns]

# %%
topic_model.get_topic_info()[:10]
# Out:
#    Topic  Count                                     Name  \
# 0     -1   3679               -1_code_function_write_use
# 1      0    314              0_time_date_null_varchar255
# 2      1    310  1_proxysetheader_1111_english_translate
# 3      2    298            2_india_router_hibiscus_cache
# 4      3    293                 3_file_com_glass_extract
# 5      4    276         4_marketing_business_media_brand
# 6      5    236                         5_mui_said_vs_pm
# 7      6    225      6_function_integers_numbers_integer
# 8      7    216        7_ingredients_recipe_food_cooking
# 9      8    200                     8_ev_june_ended_2017
#
#                                       Representation  \
# 0  [code, function, write, use, using, python, sn...
# 1  [time, date, null, varchar255, day, pixel, yea...
# 2  [proxysetheader, 1111, english, translate, mea...
# 3  [india, router, hibiscus, cache, newwidth, cre...
# 4  [file, com, glass, extract, shaker, shot, cons...
# 5  [marketing, business, media, brand, plan, stra...
# 6  [mui, said, vs, pm, gymnasium, hs, monday, 730...
# 7  [function, integers, numbers, integer, array, ...
# 8  [ingredients, recipe, food, cooking, dish, flo...
# 9  [ev, june, ended, 2017, waze, jones, months, n...
#
#                                  Representative_Docs
# 0  [Web search results:\n\n[1] "A "listicle" is a...
# 1  [Ans: August 23 , 1994\nQues: On August 23, 19...
# 2  [You are currently an online teaching platform...
# 3  [Given the text: Malvaceae week :: Hibiscus sa...
# 4  [rearrange this data in table format that incl...
# 5  [JOB ADVERTISEMENT\nMarketing Manager\nLocatio...
# 6  [Given the text: (A) 11/05/16 TBA vs Winston-S...
# 7  [You are given a list of integers and are requ...
# 8  [You will be presented with a document contain...
# 9  [Adena High School basketball went 6-16 during...
